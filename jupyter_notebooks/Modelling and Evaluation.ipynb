# %% [markdown]
# # Modelling and Evaluation

# %% [markdown]
# ## Objectives

# %% [markdown]
# * Resolve the second business requirement:
#     * The client is interested in the ability to predict whether the cherry leaf is healthy or contains powdery mildew.

# %% [markdown]
# ## Inputs

# %% [markdown]
# * inputs/cherry-leaves_dataset/cherry-leaves/train
# * inputs/cherry-leaves_dataset/cherry-leaves/test
# * inputs/cherry-leaves_dataset/cherry-leaves/validation
# * image shape embeddings

# %% [markdown]
# ## Outputs

# %% [markdown]
# * Images distribution plot in train, validation, and test set.
# * Image augmentation.
# * Class indices to change prediction inference in labels.
# * Machine learning model creation and training.
# * Save model.
# * Learning curve plot for model performance.
# * Model evaluation on pickle file.
# * Prediction on the random image file.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Import regular package

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread

# %% [markdown]
# ---

# %% [markdown]
# # Set working directory

# %%
cwd= os.getcwd()

# %%
os.chdir('/workspace/PP5-mildew-detection-in-cherry-leaves')
print("You set a new current directory")
# Out:
# You set a new current directory

# %%
work_dir = os.getcwd()
work_dir
# Out:
# '/workspace/PP5-mildew-detection-in-cherry-leaves'

# %% [markdown]
# ---

# %% [markdown]
# ## Set input directories

# %% [markdown]
# set train, validation and test paths

# %%
my_data_dir = 'inputs/cherry-leaves_dataset/cherry-leaves'
train_path = my_data_dir + '/train'
val_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %% [markdown]
# ## Set output directory

# %%
version = 'v2'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(work_dir) and version in os.listdir(work_dir + '/outputs'):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# ## Set labels

# %%
labels = os.listdir(train_path)

print(
    f"Project Labels: {labels}"
)
# Out:
# Project Labels: ['healthy', 'powdery_mildew']

# %% [markdown]
# ## Set image shape

# %%
import joblib
version = 'v2'
image_shape = joblib.load(filename=f"outputs/{version}/image_shape.pkl")
image_shape
# Out:
# (51, 51, 3)

# %% [markdown]
# ---

# %% [markdown]
# ## Number of images in train, test and validation data

# %%
df_freq = pd.DataFrame([])
for folder in ['train', 'validation', 'test']:
    for label in labels:
        df_freq = df_freq.append(
            pd.Series(data={'Set': folder,
                            'Label': label,
                            'Frequency': int(len(os.listdir(my_data_dir + '/' + folder + '/' + label)))}
                      ),
            ignore_index=True
        )

        print(
            f"* {folder} - {label}: {len(os.listdir(my_data_dir+'/'+ folder + '/' + label))} images")

print("\n")
sns.set_style("whitegrid")
plt.figure(figsize=(8, 5))
sns.barplot(data=df_freq, x='Set', y='Frequency', hue='Label')
plt.savefig(f'{file_path}/labels_distribution.png',
            bbox_inches='tight', dpi=150)
plt.show()
# Out:
# * train - healthy: 1230 images
# * train - powdery_mildew: 1237 images
# * validation - healthy: 115 images
# * validation - powdery_mildew: 165 images
# * test - healthy: 310 images
# * test - powdery_mildew: 304 images

# %% [markdown]
# ---

# %% [markdown]
# ## Image augumentation

# %% [markdown]
# ---

# %% [markdown]
# ### ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# * Initialise ImageDataGenerator

# %%
augmented_image_data = ImageDataGenerator(rotation_range=20,
                                          width_shift_range=0.10,
                                          height_shift_range=0.10,
                                          shear_range=0.1,
                                          zoom_range=0.1,
                                          horizontal_flip=True,
                                          vertical_flip=True,
                                          fill_mode='nearest',
                                          rescale=1./255
                                          )

# %% [markdown]
# * Augument training image dataset

# %%
batch_size = 20  # Set batch size
train_set = augmented_image_data.flow_from_directory(train_path,
                                                     target_size=image_shape[:2],
                                                     color_mode='rgb',
                                                     batch_size=batch_size,
                                                     class_mode='binary',
                                                     shuffle=True
                                                     )

train_set.class_indices
# Out:
# Found 2467 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# * Augument validation image dataset

# %%
validation_set = ImageDataGenerator(rescale=1./255).flow_from_directory(val_path,
                                                                        target_size=image_shape[:2],
                                                                        color_mode='rgb',
                                                                        batch_size=batch_size,
                                                                        class_mode='binary',
                                                                        shuffle=False
                                                                        )

validation_set.class_indices
# Out:
# Found 280 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# * Augument test image dataset

# %%
test_set = ImageDataGenerator(rescale=1./255).flow_from_directory(test_path,
                                                                  target_size=image_shape[:2],
                                                                  color_mode='rgb',
                                                                  batch_size=batch_size,
                                                                  class_mode='binary',
                                                                  shuffle=False
                                                                  )

test_set.class_indices
# Out:
# Found 614 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# ## Plot augumented training image

# %%
for _ in range(3):
    img, label = train_set.next()
    print(img.shape)  # (1,51,51,3)
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 51, 51, 3)
# (20, 51, 51, 3)
# (20, 51, 51, 3)

# %% [markdown]
# # Plot augumented validation and test images

# %%
for _ in range(3):
    img, label = validation_set.next()
    print(img.shape)  # (1,256,256,3)
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 51, 51, 3)
# (20, 51, 51, 3)
# (20, 51, 51, 3)

# %% [markdown]
# ## Save class_indices

# %%
joblib.dump(value=train_set.class_indices,
            filename=f"{file_path}/class_indices.pkl")
# Out:
# ['outputs/v2/class_indices.pkl']

# %% [markdown]
# ---

# %% [markdown]
# # Model creation

# %% [markdown]
# ---

# %% [markdown]
# * Import model packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
def create_tf_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3, 3),
              input_shape=image_shape, activation='relu', ))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3),
              input_shape=image_shape, activation='relu', ))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3, 3),
              input_shape=image_shape, activation='relu', ))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))

    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# * ### Model Summary

# %%
create_tf_model().summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 49, 49, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 22, 22, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               131200
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 187,649
# Trainable params: 187,649
# Non-trainable params: 0
# _________________________________________________________________
# 2024-08-04 15:40:52.244180: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# * ### Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# %% [markdown]
# # Fit model for training

# %%
model = create_tf_model()
model.fit(train_set,
          epochs=25,
          steps_per_epoch=len(train_set.classes) // batch_size,
          validation_data=validation_set,
          callbacks=[early_stop],
          verbose=1
          )
# Out:
# 2024-08-04 15:41:12.277574: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/25
# 123/123 [==============================] - 10s 74ms/step - loss: 0.4466 - accuracy: 0.7732 - val_loss: 0.1505 - val_accuracy: 0.9429
# Epoch 2/25
# 123/123 [==============================] - 5s 37ms/step - loss: 0.2253 - accuracy: 0.9097 - val_loss: 0.0888 - val_accuracy: 0.9643
# Epoch 3/25
# 123/123 [==============================] - 5s 38ms/step - loss: 0.1473 - accuracy: 0.9465 - val_loss: 0.0703 - val_accuracy: 0.9786
# Epoch 4/25
# 123/123 [==============================] - 5s 38ms/step - loss: 0.1172 - accuracy: 0.9587 - val_loss: 0.2410 - val_accuracy: 0.9000
# Epoch 5/25
# 123/123 [==============================] - 5s 39ms/step - loss: 0.1116 - accuracy: 0.9624 - val_loss: 0.1095 - val_accuracy: 0.9536
# Epoch 6/25
# 123/123 [==============================] - 5s 37ms/step - loss: 0.0617 - accuracy: 0.9800 - val_loss: 0.0242 - val_accuracy: 0.9893
# Epoch 7/25
# 123/123 [==============================] - 5s 37ms/step - loss: 0.0555 - accuracy: 0.9824 - val_loss: 0.0237 - val_accuracy: 0.9929
# Epoch 8/25
# 123/123 [==============================] - 8s 69ms/step - loss: 0.0500 - accuracy: 0.9865 - val_loss: 0.0220 - val_accuracy: 0.9893
# Epoch 9/25
# 123/123 [==============================] - 8s 68ms/step - loss: 0.0515 - accuracy: 0.9837 - val_loss: 0.0147 - val_accuracy: 0.9964
# Epoch 10/25
# 123/123 [==============================] - 5s 38ms/step - loss: 0.0404 - accuracy: 0.9881 - val_loss: 0.0138 - val_accuracy: 0.9929
# Epoch 11/25
# 123/123 [==============================] - 5s 38ms/step - loss: 0.0382 - accuracy: 0.9873 - val_loss: 0.0374 - val_accuracy: 0.9821
# Epoch 12/25
# 123/123 [==============================] - 5s 37ms/step - loss: 0.0518 - accuracy: 0.9837 - val_loss: 0.0255 - val_accuracy: 0.9929
# Epoch 13/25
# 123/123 [==============================] - 5s 37ms/step - loss: 0.0264 - accuracy: 0.9918 - val_loss: 0.0072 - val_accuracy: 0.9964
# Epoch 14/25
# 123/123 [==============================] - 5s 37ms/step - loss: 0.0128 - accuracy: 0.9947 - val_loss: 0.0343 - val_accuracy: 0.9857
# Epoch 15/25
# 123/123 [==============================] - 5s 37ms/step - loss: 0.0424 - accuracy: 0.9853 - val_loss: 0.0971 - val_accuracy: 0.9536
# Epoch 16/25
# 123/123 [==============================] - 5s 37ms/step - loss: 0.0260 - accuracy: 0.9922 - val_loss: 0.0075 - val_accuracy: 0.9964

# %% [markdown]
# # Save model

# %%
model.save('outputs/v2/mildew_detector_in_cherry_leaves_model.h5')

# %% [markdown]
# ---

# %% [markdown]
# # Model Performance

# %% [markdown]
# ---

# %%
losses = pd.DataFrame(model.history.history)

sns.set_style("whitegrid")
losses[['loss', 'val_loss']].plot(style='.-')
plt.title("Loss")
plt.savefig(f'{file_path}/model_training_losses.png',
            bbox_inches='tight', dpi=150)
plt.show()

print("\n")
losses[['accuracy', 'val_accuracy']].plot(style='.-')
plt.title("Accuracy")
plt.savefig(f'{file_path}/model_training_acc.png',
            bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# load saved model

# %%
from keras.models import load_model
model = load_model('outputs/v2/mildew_detector_in_cherry_leaves_model.h5')

# %% [markdown]
# Evaluate model on test set

# %%
evaluation = model.evaluate(test_set)
# Out:
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0022 - accuracy: 1.0000

# %% [markdown]
# ### Save evaluation pickle

# %%
joblib.dump(value=evaluation,
            filename=f"outputs/v2/evaluation.pkl")
# Out:
# ['outputs/v2/evaluation.pkl']

# %% [markdown]
# # Predict on new data

# %% [markdown]
# Load a random image as PIL

# %%
from tensorflow.keras.preprocessing import image

pointer = 66
label = labels[0]  # select healthy or powdery_mildew

pil_image = image.load_img(test_path + '/' + label + '/' + os.listdir(test_path+'/' + label)[pointer],
                           target_size=image_shape, color_mode='rgb')
print(f'Image shape: {pil_image.size}, Image mode: {pil_image.mode}')
pil_image
# Out:
# Image shape: (51, 51), Image mode: RGB
# <PIL.Image.Image image mode=RGB size=51x51>

# %% [markdown]
# Convert image to array to prepare for prediction

# %%
my_image = image.img_to_array(pil_image)
my_image = np.expand_dims(my_image, axis=0)/255
print(my_image.shape)
# Out:
# (1, 51, 51, 3)

# %% [markdown]
# Predict class probabilities

# %%
pred_proba = model.predict(my_image)[0, 0]

target_map = {v: k for k, v in train_set.class_indices.items()}
pred_class = target_map[pred_proba > 0.5]

if pred_class == target_map[0]:
    pred_proba = 1 - pred_proba

print(pred_proba)
print(pred_class)
# Out:
# 0.9999999960011436
# healthy
